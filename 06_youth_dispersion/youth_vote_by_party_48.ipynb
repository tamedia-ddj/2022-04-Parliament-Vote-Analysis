# %%
import os, sys
import pandas as pd
import matplotlib.pyplot as plt

sys.path.insert(1, os.path.join(sys.path[0], "../00_helpers"))
from helpers import get_rice_index

# %%
BOLD = '\033[1m'
CLEAR = '\033[0m'
AGE_THRESHOLD = 48

# %%
df = pd.read_csv("../processed_data/votes_finaux.csv")
dfp = pd.read_csv("../processed_data/parlementaires_with_age.csv")
dfp.rename(columns={"Unnamed: 0.1.1": "id"}, inplace=True)

# %%
# Helper
def get_splitted_share(group_a, group_b, vote_column="vote"):
    """Get share of “yes” votes for two groups"""
    len_yes_a = len(group_a[group_a[vote_column] == "Oui"])
    len_yes_b = len(group_b[group_b[vote_column] == "Oui"])
    len_yesno_a = len(group_a[group_a[vote_column].isin(["Oui", "Non"])])
    len_yesno_b = len(group_b[group_b[vote_column].isin(["Oui", "Non"])])
    share_yes_a = len_yes_a / len_yesno_a * 100
    share_yes_b = len_yes_b / len_yesno_b * 100
    return {
        f"Oui >{AGE_THRESHOLD}": len_yes_a,
        f"Oui <={AGE_THRESHOLD}": len_yes_b,
        f"Oui/Non >{AGE_THRESHOLD}": len_yesno_a,
        f"Oui/Non <={AGE_THRESHOLD}": len_yesno_b,
        f"Oui >{AGE_THRESHOLD} (%)": share_yes_a,
        f"Oui <={AGE_THRESHOLD} (%)": share_yes_b,
        "Différence (%)": abs(share_yes_a - share_yes_b),
    }

# %% [markdown]
# ### Select political parties with at least 5 councillors

# %%
party_count = pd.DataFrame(dfp["party"].value_counts())
party_count.columns = ["count"]
selected_parties = party_count[party_count["count"] > 4]

# %%
# ! Doublons parmi les votes finaux
df[df.AffairTitle.duplicated()].shape
# Out:
# (49, 318)

# %%
# En cas de doublon, pour le moment, on ne garde que le dernier vote
df = df.sort_values("VoteDate").drop_duplicates(
    subset="AffairTitle", keep="last"
).set_index("AffairTitle").copy()
len(df)
# Out:
# 303

# %% [markdown]
# ## Get votes with largest young/old gap

# %%
party_delta = {}
for party_name in selected_parties.index:
    councillor_ids_old = [
        str(i) for i in dfp[(dfp["party"] == party_name) & (dfp["Age"] > 48)]["id"]
    ]
    councillor_ids_young = [
        str(i) for i in dfp[(dfp["party"] == party_name) & (dfp["Age"] <= 48)]["id"]
    ]

    print(
        f"\n{BOLD}{party_name}{CLEAR}:\n {len(councillor_ids_old)} >= 48\n {len(councillor_ids_young)} < 48"
    )

    if len(councillor_ids_young) > 0:
        df_votes_old = df[councillor_ids_old].T.copy()
        df_votes_young = df[councillor_ids_young].T.copy()

        votes = []
        for col in df_votes_young.columns:
            len_votes = len(df_votes_young[df_votes_young[col].isin(["Oui", "Non"])])
            if len_votes == 0:
                # print("No yes/no vote for", col)
                pass
            else:
                vote_share = get_splitted_share(df_votes_old, df_votes_young, vote_column=col)
                vote_share["Date"] = df.T[col]["VoteDate"]
                vote_share["Objet"] = col
                votes.append(vote_share)
        dfv = pd.DataFrame(votes)
        print(f"\nTop 2 objects with largest gap:")
        dfv.sort_values("Différence (%)", ascending=False).head(5).apply(
            lambda row: print(
                f"Delta: {round(row['Différence (%)'], 1)} percent points, %yes <48: {round(row[f'Oui <={AGE_THRESHOLD} (%)'])}% ({row[f'Oui <={AGE_THRESHOLD}']}/{row[f'Oui/Non <={AGE_THRESHOLD}']}), %yes >=48: {round(row[f'Oui >{AGE_THRESHOLD}'])}%. Objet: {row['Objet']} ({row['Date']})"
            ),
            axis=1,
        )
        party_delta[party_name] = dfv
    else:
        print("No councillor < 48 => no comparison")
# Out:
# UDC:
#  54 >= 48
#  26 < 48
#
# Top 2 objects with largest gap:
# Delta: 32.8 percent points, %yes <48: 50% (10/20), %yes >=48: 5%. Objet: Stop à l’îlot de cherté – pour des prix équitables. Initiative populaire et contre-projet indirect (2021-03-19 09:20:13)
# Delta: 27.1 percent points, %yes <48: 47% (8/17), %yes >=48: 6%. Objet: Mariage civil pour tous (2020-12-18 08:45:07)
# Delta: 25.3 percent points, %yes <48: 29% (4/14), %yes >=48: 21%. Objet: Double imposition. Convention avec le Liechtenstein (2016-06-17 09:44:40)
# Delta: 20.1 percent points, %yes <48: 6% (1/16), %yes >=48: 5%. Objet: Doubles impositions. Convention avec la Nouvelle-Zélande (2020-06-19 10:21:28)
# Delta: 19.6 percent points, %yes <48: 8% (1/13), %yes >=48: 9%. Objet: Double imposition. Convention avec la Norvège (2016-06-17 09:45:26)
#
# PSS:
#  40 >= 48
#  24 < 48
#
# Top 2 objects with largest gap:
# Delta: 33.3 percent points, %yes <48: 71% (5/7), %yes >=48: 8%. Objet: Pour un revenu de base inconditionnel. Initiative populaire (2015-12-18 08:18:29)
# Delta: 30.0 percent points, %yes <48: 70% (7/10), %yes >=48: 28%. Objet: Ancrer durablement le taux spécial de TVA applicable à l'hébergement (2017-06-16 08:46:16)
# Delta: 26.4 percent points, %yes <48: 62% (5/8), %yes >=48: 24%. Objet: Loi sur la surveillance de la correspondance par poste et télécommunication. Modification (2016-03-18 09:12:25)
# Delta: 22.2 percent points, %yes <48: 78% (7/9), %yes >=48: 27%. Objet: Projet fiscal 17 (2018-09-28 10:47:10)
# Delta: 20.4 percent points, %yes <48: 18% (3/17), %yes >=48: 8%. Objet: Révision partielle urgente de la loi fédérale sur l'aviation face à la crise Covid-19 (2020-05-06 13:07:51)
#
# PLR:
#  31 >= 48
#  11 < 48
#
# Top 2 objects with largest gap:
# Delta: 42.3 percent points, %yes <48: 29% (2/7), %yes >=48: 17%. Objet: Charte européenne de l'autonomie locale. Protocole additionnel (2017-03-17 08:54:54)
# Delta: 39.1 percent points, %yes <48: 0% (0/5), %yes >=48: 9%. Objet: Transformation et extension des réseaux électriques. Loi (2017-12-15 09:31:44)
# Delta: 33.3 percent points, %yes <48: 57% (4/7), %yes >=48: 19%. Objet: Loi sur les jeux d’argent (2017-09-29 08:56:28)
# Delta: 31.2 percent points, %yes <48: 50% (5/10), %yes >=48: 13%. Objet: Encouragement de la culture pour la période de 2021 à 2024 (2021-10-01 08:41:48)
# Delta: 29.8 percent points, %yes <48: 43% (3/7), %yes >=48: 3%. Objet: Aides financières à l’accueil extra-familial pour enfants. Modification (2017-06-16 08:47:48)
#
# VERT-E-S:
#  14 >= 48
#  19 < 48
#
# Top 2 objects with largest gap:
# Delta: 66.7 percent points, %yes <48: 33% (1/3), %yes >=48: 4%. Objet: Pour un revenu de base inconditionnel. Initiative populaire (2015-12-18 08:18:29)
# Delta: 40.0 percent points, %yes <48: 0% (0/4), %yes >=48: 2%. Objet: Projet fiscal 17 (2018-09-28 10:47:10)
# Delta: 33.3 percent points, %yes <48: 67% (2/3), %yes >=48: 7%. Objet: Pour une monnaie à l’abri des crises: émission monétaire uniquement par la Banque nationale! (Initiative Monnaie pleine). Initiative populaire (2017-12-15 09:32:36)
# Delta: 16.7 percent points, %yes <48: 0% (0/3), %yes >=48: 1%. Objet: Loi sur l'imposition des huiles minérales. Révision partielle (2016-03-18 09:20:55)
# Delta: 15.9 percent points, %yes <48: 9% (1/11), %yes >=48: 2%. Objet: Oui à l’interdiction de se dissimuler le visage. Initiative populaire et contre-projet indirect (2020-06-19 10:04:48)
#
# M-E:
#  23 >= 48
#  8 < 48
#
# Top 2 objects with largest gap:
# Delta: 43.4 percent points, %yes <48: 75% (6/8), %yes >=48: 6%. Objet: Loi sur le service civil. Modification (2020-06-19 10:03:06)
# Delta: 35.9 percent points, %yes <48: 33% (1/3), %yes >=48: 9%. Objet: CC. Droit de l’adoption. Modification (2016-06-17 09:17:29)
# Delta: 33.3 percent points, %yes <48: 67% (2/3), %yes >=48: 15%. Objet: Révision de l’imposition à la source du revenu de l’activité lucrative. Loi (2016-12-16 08:17:15)
# Delta: 28.9 percent points, %yes <48: 50% (3/6), %yes >=48: 15%. Objet: Développement de la production d'électricité d'origine hydraulique. Revoir la situation de référence des études d'impact (2019-12-20 08:58:20)
# Delta: 19.0 percent points, %yes <48: 67% (2/3), %yes >=48: 12%. Objet: Charte européenne de l'autonomie locale. Protocole additionnel (2017-03-17 08:54:54)
#
# pvl:
#  12 >= 48
#  7 < 48
#
# Top 2 objects with largest gap:
# Delta: 66.7 percent points, %yes <48: 100% (2/2), %yes >=48: 1%. Objet: Loi sur les travailleurs détachés. Modification (2016-09-30 09:09:48)
# Delta: 50.0 percent points, %yes <48: 50% (1/2), %yes >=48: 5%. Objet: Relever l'examen de contrôle périodique effectué par un médecin-conseil de 70 à 75 ans pour les conducteurs âgés (2017-09-29 08:57:36)
# Delta: 42.9 percent points, %yes <48: 0% (0/5), %yes >=48: 3%. Objet: Pour une Suisse libre de pesticides de synthèse. Initiative populaire (2020-09-25 09:46:41)
# Delta: 32.7 percent points, %yes <48: 40% (2/5), %yes >=48: 8%. Objet: CO. Droit de la société anonyme (2020-06-19 09:56:05)
# Delta: 30.0 percent points, %yes <48: 0% (0/5), %yes >=48: 3%. Objet: Entreprises responsables – pour protéger l’être humain et l’environnement. Initiative populaire (2020-06-19 09:58:36)
#
# PDC:
#  8 >= 48
#  2 < 48
#
# Top 2 objects with largest gap:
# Delta: 37.5 percent points, %yes <48: 50% (1/2), %yes >=48: 7%. Objet: CC. Droit de l’adoption. Modification (2016-06-17 09:17:29)
# Delta: 0.0 percent points, %yes <48: 100% (2/2), %yes >=48: 8%. Objet: Importations de viande assaisonnée. Abolition du traitement préférentiel prévu dans le tarif douanier (2015-12-18 08:14:28)
# Delta: 0.0 percent points, %yes <48: 100% (2/2), %yes >=48: 7%. Objet: Loi sur les jeux d’argent (2017-09-29 08:56:28)
# Delta: 0.0 percent points, %yes <48: 100% (2/2), %yes >=48: 7%. Objet: Transport régional de voyageurs 2018-2021. Crédit d‘engagement (2017-06-16 08:53:26)
# Delta: 0.0 percent points, %yes <48: 100% (2/2), %yes >=48: 7%. Objet: Convention du Conseil de l’Europe sur la prévention et la lutte contre la violence à l’égard des femmes (convention d’Istanbul). Approbation (2017-06-16 08:59:18)
#
# PBD:
#  5 >= 48
#  0 < 48
# No councillor < 48 => no comparison

# %%
# Results for 6 political parties with enough <40 y.o. councillors
party_delta.keys()
# Out:
# dict_keys(['UDC', 'PSS', 'PLR', 'VERT-E-S', 'M-E', 'pvl', 'PDC'])

# %%
# Example usage
party_delta['PSS'].sort_values('Différence (%)', ascending=False).head(20).round(1)
# Out:
#      Oui >48  Oui <=48  Oui/Non >48  Oui/Non <=48  Oui >48 (%)  Oui <=48 (%)  \
# 4          8         5           21             7         38.1          71.4
# 87        28         7           28            10        100.0          70.0
# 13        24         5           27             8         88.9          62.5
# 144       27         7           27             9        100.0          77.8
# 155        8         3           21            17         38.1          17.6
# 116        4         0           20             8         20.0           0.0
# 120        9         3           16             7         56.2          42.9
# 262       19        15           19            17        100.0          88.2
# 124        3         0           27            10         11.1           0.0
# 114        3         0           29            10         10.3           0.0
# 129        3         2           25            10         12.0          20.0
# 111       17         7           21             8         81.0          87.5
# 113       27         9           28            10         96.4          90.0
# 261       13        10           18            15         72.2          66.7
# 132        1         0           20             6          5.0           0.0
# 259       13         9           15            11         86.7          81.8
# 0          1         0           30            10          3.3           0.0
# 214       20        14           21            15         95.2          93.3
# 248       11         9           17            14         64.7          64.3
# 194       21        17           21            17        100.0         100.0
#
#      Différence (%)                 Date  \
# 4              33.3  2015-12-18 08:18:29
# 87             30.0  2017-06-16 08:46:16
# 13             26.4  2016-03-18 09:12:25
# 144            22.2  2018-09-28 10:47:10
# 155            20.4  2020-05-06 13:07:51
# 116            20.0  2018-03-16 08:20:49
# 120            13.4  2018-03-16 08:26:45
# 262            11.8  2021-10-01 08:49:49
# 124            11.1  2018-03-16 08:38:01
# 114            10.3  2017-12-15 09:35:42
# 129             8.0  2018-06-15 09:42:02
# 111             6.5  2017-12-15 09:32:36
# 113             6.4  2017-12-15 09:34:43
# 261             5.6  2021-10-01 08:48:46
# 132             5.0  2018-06-15 09:48:02
# 259             4.8  2021-10-01 08:47:10
# 0               3.3  2015-12-18 08:14:28
# 214             1.9  2020-12-18 08:52:53
# 248             0.4  2021-10-01 08:36:46
# 194             0.0  2020-09-25 09:52:21
#
#                                                  Objet
# 4    Pour un revenu de base inconditionnel. Initiat...
# 87   Ancrer durablement le taux spécial de TVA appl...
# 13   Loi sur la surveillance de la correspondance p...
# 144                                   Projet fiscal 17
# 155  Révision partielle urgente de la loi fédérale ...
# 116  Pour des denrées alimentaires saines et produi...
# 120  Pour la souveraineté alimentaire. L’agricultur...
# 262  Adaptation de l'âge limite en vigueur au sein ...
# 124  Pour la promotion des voies cyclables et des c...
# 114  Décision de l’OMC en matière de concurrence à ...
# 129  Pour la dignité des animaux de rente agricoles...
# 111  Pour une monnaie à l’abri des crises: émission...
# 113  Développement de l'acquis de Schengen. Reprise...
# 261  Frais pour l'accueil extrafamilial. Déduction ...
# 132  Stopper le mitage - pour un développement dura...
# 259  Pour sauver des vies en favorisant le don d'or...
# 0    Importations de viande assaisonnée. Abolition ...
# 214  Développement de l'acquis de Schengen. Système...
# 248  Stop au bradage ruineux du sucre! Pour la sauv...
# 194  Loi sur les précurseurs de substances explosibles

# %%
pd.options.display.max_colwidth = 200

# %%
# UDC
df_party = party_delta['UDC'].sort_values('Différence (%)', ascending=False).head(10).round(1)
df_party = df_party[['Objet', 'Différence (%)', 'Oui <=48 (%)', 'Oui >48 (%)', 'Oui <=48', 'Oui/Non <=48', 'Oui >48', 'Oui/Non >48', 
        'Date']]
blankIndex=[''] * len(df_party)
df_party.index=blankIndex
df_party
# Out:
#                                                                                                                                                                                                     Objet  \
#                                                                                                        Stop à l’îlot de cherté – pour des prix équitables. Initiative populaire et contre-projet indirect
#                                                                                                                                                                                   Mariage civil pour tous
#                                                                                                                                                       Double imposition. Convention avec le Liechtenstein
#                                                                                                                                                  Doubles impositions. Convention avec la Nouvelle-Zélande
#                                                                                                                                                             Double imposition. Convention avec la Norvège
#                                                                                                                                                                               Loi sur les amendes d‘ordre
#                                                                                                                                                                                 Loi sur les jeux d’argent
#                                                                                                                                           Exonérer les enfants du paiement des primes d'assurance-maladie
#   Développement de l'acquis de Schengen. Approbation et mise en oeuvre des échanges de notes entre la Suisse et l’UE concernant la reprise des règlements (UE) 2019/817 et 2019/818 relatifs à l’établ...
#                                                                                                                                         Améliorer la capacité d'action du Parlement en situation de crise
#
#   Différence (%)  Oui <=48 (%)  Oui >48 (%)  Oui <=48  Oui/Non <=48  Oui >48  \
#             32.8          50.0         17.2        10            20        5
#             27.1          47.1         20.0         8            17        6
#             25.3          28.6         53.8         4            14       21
#             20.1           6.2         26.3         1            16        5
#             19.6           7.7         27.3         1            13        9
#             18.4          76.9         95.3        10            13       41
#             18.3          14.3         32.6         2            14       15
#             17.8          80.0         97.8        12            15       44
#             17.1          70.0         87.1        14            20       27
#             16.7          50.0         33.3         9            18        9
#
#   Oui/Non >48                 Date
#            29  2021-03-19 09:20:13
#            30  2020-12-18 08:45:07
#            39  2016-06-17 09:44:40
#            19  2020-06-19 10:21:28
#            33  2016-06-17 09:45:26
#            43  2016-03-18 09:20:11
#            46  2017-09-29 08:56:28
#            45  2017-03-17 08:41:30
#            31  2021-03-19 09:30:18
#            27  2022-03-18 09:12:56

# %%
# PSS
df_party = party_delta['PSS'].sort_values('Différence (%)', ascending=False).head(10).round(1)
df_party = df_party[['Objet', 'Différence (%)', 'Oui <=48 (%)', 'Oui >48 (%)', 'Oui <=48', 'Oui/Non <=48', 'Oui >48', 'Oui/Non >48', 
        'Date']]
blankIndex=[''] * len(df_party)
df_party.index=blankIndex
df_party
# Out:
#                                                                                                                                                             Objet  \
#                                                                                                       Pour un revenu de base inconditionnel. Initiative populaire
#                                                                                              Ancrer durablement le taux spécial de TVA applicable à l'hébergement
#                                                                         Loi sur la surveillance de la correspondance par poste et télécommunication. Modification
#                                                                                                                                                  Projet fiscal 17
#                                                                             Révision partielle urgente de la loi fédérale sur l'aviation face à la crise Covid-19
#   Pour des denrées alimentaires saines et produites dans des conditions équitables et écologiques (initiative pour des aliments équitables). Initiative populaire
#                                                                Pour la souveraineté alimentaire. L’agriculture nous concerne toutes et tous. Initiative populaire
#                                                                             Adaptation de l'âge limite en vigueur au sein du Ministère public de la Confédération
#                                                Pour la promotion des voies cyclables et des chemins et sentiers pédestres (initiative vélo). Initiative populaire
#                Décision de l’OMC en matière de concurrence à l’exportation. Suppression des contributions à l’exportation pour les produits agricoles transformés
#
#   Différence (%)  Oui <=48 (%)  Oui >48 (%)  Oui <=48  Oui/Non <=48  Oui >48  \
#             33.3          71.4         38.1         5             7        8
#             30.0          70.0        100.0         7            10       28
#             26.4          62.5         88.9         5             8       24
#             22.2          77.8        100.0         7             9       27
#             20.4          17.6         38.1         3            17        8
#             20.0           0.0         20.0         0             8        4
#             13.4          42.9         56.2         3             7        9
#             11.8          88.2        100.0        15            17       19
#             11.1           0.0         11.1         0            10        3
#             10.3           0.0         10.3         0            10        3
#
#   Oui/Non >48                 Date
#            21  2015-12-18 08:18:29
#            28  2017-06-16 08:46:16
#            27  2016-03-18 09:12:25
#            27  2018-09-28 10:47:10
#            21  2020-05-06 13:07:51
#            20  2018-03-16 08:20:49
#            16  2018-03-16 08:26:45
#            19  2021-10-01 08:49:49
#            27  2018-03-16 08:38:01
#            29  2017-12-15 09:35:42

# %%
# PLR
df_party = party_delta['PLR'].sort_values('Différence (%)', ascending=False).head(10).round(1)
df_party = df_party[['Objet', 'Différence (%)', 'Oui <=48 (%)', 'Oui >48 (%)', 'Oui <=48', 'Oui/Non <=48', 'Oui >48', 'Oui/Non >48', 
        'Date']]
blankIndex=[''] * len(df_party)
df_party.index=blankIndex
df_party
# Out:
#                                                                                                 Objet  \
#                                        Charte européenne de l'autonomie locale. Protocole additionnel
#                                              Transformation et extension des réseaux électriques. Loi
#                                                                             Loi sur les jeux d’argent
#                                            Encouragement de la culture pour la période de 2021 à 2024
#                               Aides financières à l’accueil extra-familial pour enfants. Modification
#                                                                                      Projet fiscal 17
#   Organisation internationale du Travail. Protocole à la convention no 29 concernant le travail forcé
#                           Echange international automatique de renseignements en matière fiscale. Loi
#        Assistance administrative fiscale. Convention du Conseil de l’Europe et de l’OCDE. Approbation
#     Blocage et restitution des avoirs illicites de personnes politiquement exposées à l’étranger. Loi
#
#   Différence (%)  Oui <=48 (%)  Oui >48 (%)  Oui <=48  Oui/Non <=48  Oui >48  \
#             42.3          28.6         70.8         2             7       17
#             39.1           0.0         39.1         0             5        9
#             33.3          57.1         90.5         4             7       19
#             31.2          50.0         81.2         5            10       13
#             29.8          42.9         13.0         3             7        3
#             28.8          66.7         95.5         4             6       21
#             27.5          60.0         87.5         3             5       21
#             25.0          75.0        100.0         3             4       22
#             25.0          75.0        100.0         3             4       22
#             20.0          80.0        100.0         4             5       23
#
#   Oui/Non >48                 Date
#            24  2017-03-17 08:54:54
#            23  2017-12-15 09:31:44
#            21  2017-09-29 08:56:28
#            16  2021-10-01 08:41:48
#            23  2017-06-16 08:47:48
#            22  2018-09-28 10:47:10
#            24  2017-03-17 08:53:49
#            22  2015-12-18 08:24:33
#            22  2015-12-18 08:25:34
#            23  2015-12-18 08:17:31

# %%
# VERT-E-S
df_party = party_delta['VERT-E-S'].sort_values('Différence (%)', ascending=False).head(10).round(1)
df_party = df_party[['Objet', 'Différence (%)', 'Oui <=48 (%)', 'Oui >48 (%)', 'Oui <=48', 'Oui/Non <=48', 'Oui >48', 'Oui/Non >48', 
        'Date']]
blankIndex=[''] * len(df_party)
df_party.index=blankIndex
df_party
# Out:
#                                                                                                                                                                                        Objet  \
#                                                                                                                                  Pour un revenu de base inconditionnel. Initiative populaire
#                                                                                                                                                                             Projet fiscal 17
#                                               Pour une monnaie à l’abri des crises: émission monétaire uniquement par la Banque nationale! (Initiative Monnaie pleine). Initiative populaire
#                                                                                                                                Loi sur l'imposition des huiles minérales. Révision partielle
#                                                                                              Oui à l’interdiction de se dissimuler le visage. Initiative populaire et contre-projet indirect
#   Pour une eau potable propre et une alimentation saine - Pas de subventions pour l'utilisation de pesticides et l'utilisation d'antibiotiques à titre prophylactiques. Initiative populaire
#                                                                                                                LAVS. Modification (Utilisation systématique du numéro AVS par les autorités)
#                                                                                                                                                                   Loi COVID-19. Modification
#                                                        Indemnité forfaitaire octroyée pour la taxe sur la valeur ajoutée perçue sur la redevance de réception de radio et de télévision. Loi
#                                                                                                                                         LACI. Financement additionnel de l'assurance-chômage
#
#   Différence (%)  Oui <=48 (%)  Oui >48 (%)  Oui <=48  Oui/Non <=48  Oui >48  \
#             66.7          33.3        100.0         1             3        4
#             40.0           0.0         40.0         0             4        2
#             33.3          66.7        100.0         2             3        7
#             16.7           0.0         16.7         0             3        1
#             15.9           9.1         25.0         1            11        2
#              6.7           6.7          0.0         1            15        0
#              3.3           6.7         10.0         1            15        1
#              0.0         100.0        100.0        16            16       10
#              0.0         100.0        100.0        15            15       10
#              0.0         100.0        100.0        15            15        9
#
#   Oui/Non >48                 Date
#             4  2015-12-18 08:18:29
#             5  2018-09-28 10:47:10
#             7  2017-12-15 09:32:36
#             6  2016-03-18 09:20:55
#             8  2020-06-19 10:04:48
#            10  2020-09-25 09:45:17
#            10  2020-12-18 08:49:07
#            10  2020-12-18 08:57:41
#            10  2020-09-25 09:55:38
#             9  2020-09-25 10:03:18

# %%
# M-E
df_party = party_delta['M-E'].sort_values('Différence (%)', ascending=False).head(10).round(1)
df_party = df_party[['Objet', 'Différence (%)', 'Oui <=48 (%)', 'Oui >48 (%)', 'Oui <=48', 'Oui/Non <=48', 'Oui >48', 'Oui/Non >48', 
        'Date']]
blankIndex=[''] * len(df_party)
df_party.index=blankIndex
df_party
# Out:
#                                                                                                                                                    Objet  \
#                                                                                                                   Loi sur le service civil. Modification
#                                                                                                                    CC. Droit de l’adoption. Modification
#                                                                              Révision de l’imposition à la source du revenu de l’activité lucrative. Loi
#                                 Développement de la production d'électricité d'origine hydraulique. Revoir la situation de référence des études d'impact
#                                                                                           Charte européenne de l'autonomie locale. Protocole additionnel
#   Oui à la protection des enfants et des jeunes contre la publicité pour le tabac (enfants et jeunes sans publicité pour le tabac). Initiative populaire
#                                                                                                                          CO. Droit de la société anonyme
#                                                                                   Loi sur les stupéfiants. Modification (Médicaments à base de cannabis)
#                                                                                               Encouragement de la culture pour la période de 2021 à 2024
#                                 Pour plus de transparence dans le financement de la vie politique (initiative sur la transparence). Initiative populaire
#
#   Différence (%)  Oui <=48 (%)  Oui >48 (%)  Oui <=48  Oui/Non <=48  Oui >48  \
#             43.4          75.0         31.6         6             8        6
#             35.9          33.3         69.2         1             3        9
#             33.3          66.7        100.0         2             3       15
#             28.9          50.0         78.9         3             6       15
#             19.0          66.7         85.7         2             3       12
#             15.0          80.0         95.0         4             5       19
#             14.3          85.7        100.0         6             7       20
#             14.3          85.7        100.0         6             7       18
#             12.8          71.4         84.2         5             7       16
#             12.5          87.5        100.0         7             8       19
#
#   Oui/Non >48                 Date
#            19  2020-06-19 10:03:06
#            13  2016-06-17 09:17:29
#            15  2016-12-16 08:17:15
#            19  2019-12-20 08:58:20
#            14  2017-03-17 08:54:54
#            20  2021-10-01 08:45:45
#            20  2020-06-19 09:56:05
#            18  2021-03-19 09:27:15
#            19  2021-10-01 08:41:48
#            19  2021-06-18 08:27:38

# %%
# PVL
df_party = party_delta['pvl'].sort_values('Différence (%)', ascending=False).head(10).round(1)
df_party = df_party[['Objet', 'Différence (%)', 'Oui <=48 (%)', 'Oui >48 (%)', 'Oui <=48', 'Oui/Non <=48', 'Oui >48', 'Oui/Non >48', 
        'Date']]
blankIndex=[''] * len(df_party)
df_party.index=blankIndex
df_party
# Out:
#                                                                                                                                                    Objet  \
#                                                                                                          Loi sur les travailleurs détachés. Modification
#                                         Relever l'examen de contrôle périodique effectué par un médecin-conseil de 70 à 75 ans pour les conducteurs âgés
#                                                                                    Pour une Suisse libre de pesticides de synthèse. Initiative populaire
#                                                                                                                          CO. Droit de la société anonyme
#                                                          Entreprises responsables – pour protéger l’être humain et l’environnement. Initiative populaire
#       Décision de l’OMC en matière de concurrence à l’exportation. Suppression des contributions à l’exportation pour les produits agricoles transformés
#                                                                Loi sur la surveillance de la correspondance par poste et télécommunication. Modification
#   Oui à la protection des enfants et des jeunes contre la publicité pour le tabac (enfants et jeunes sans publicité pour le tabac). Initiative populaire
#                                                                                                       Prestation transitoire pour les chômeurs âgés. Loi
#                                                              Pour des soins infirmiers forts (initiative sur les soins infirmiers). Initiative populaire
#
#   Différence (%)  Oui <=48 (%)  Oui >48 (%)  Oui <=48  Oui/Non <=48  Oui >48  \
#             66.7         100.0         33.3         2             2        1
#             50.0          50.0        100.0         1             2        5
#             42.9           0.0         42.9         0             5        3
#             32.7          40.0         72.7         2             5        8
#             30.0           0.0         30.0         0             5        3
#             20.0           0.0         20.0         0             1        1
#             20.0         100.0         80.0         2             2        4
#             20.0           0.0         20.0         0             5        2
#             10.0         100.0         90.0         5             5        9
#             10.0         100.0         90.0         4             4        9
#
#   Oui/Non >48                 Date
#             3  2016-09-30 09:09:48
#             5  2017-09-29 08:57:36
#             7  2020-09-25 09:46:41
#            11  2020-06-19 09:56:05
#            10  2020-06-19 09:58:36
#             5  2017-12-15 09:35:42
#             5  2016-03-18 09:12:25
#            10  2021-10-01 08:45:45
#            10  2020-06-19 10:13:50
#            10  2021-06-18 08:28:32
