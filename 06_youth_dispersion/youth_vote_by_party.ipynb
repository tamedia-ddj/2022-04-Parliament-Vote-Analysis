# %%
import os, sys
import pandas as pd
import matplotlib.pyplot as plt

sys.path.insert(1, os.path.join(sys.path[0], "../00_helpers"))
from helpers import get_rice_index, get_splitted_share

# %%
BOLD = '\033[1m'
CLEAR = '\033[0m'

# %%
df = pd.read_csv("../processed_data/votes_finaux.csv")
dfp = pd.read_csv("../processed_data/parlementaires_with_age.csv")
dfp.rename(columns={"Unnamed: 0.1.1": "id"}, inplace=True)

# %% [markdown]
# ### Select political parties with at least 5 councillors

# %%
party_count = pd.DataFrame(dfp["party"].value_counts())
party_count.columns = ["count"]
selected_parties = party_count[party_count["count"] > 4]

# %%
# ! Doublons parmi les votes finaux
df[df.AffairTitle.duplicated()].shape
# Out:
# (49, 318)

# %%
# En cas de doublon, pour le moment, on ne garde que le dernier vote
df = df.sort_values("VoteDate").drop_duplicates(
    subset="AffairTitle", keep="last"
).set_index("AffairTitle").copy()
len(df)
# Out:
# 303

# %% [markdown]
# ## Get votes with largest young/old gap

# %%
party_delta = {}
for party_name in selected_parties.index:
    councillor_ids_a = [
        str(i) for i in dfp[(dfp["party"] == party_name) & (dfp["Age"] >= 40)]["id"]
    ]
    councillor_ids_b = [
        str(i) for i in dfp[(dfp["party"] == party_name) & (dfp["Age"] < 40)]["id"]
    ]

    print(
        f"\n{BOLD}{party_name}{CLEAR}:\n {len(councillor_ids_a)} >= 40\n {len(councillor_ids_b)} < 40"
    )

    if len(councillor_ids_b) > 0:
        df_votes_a = df[councillor_ids_a].T.copy()
        df_votes_b = df[councillor_ids_b].T.copy()

        votes = []
        for col in df_votes_b.columns:
            len_votes = len(df_votes_b[df_votes_b[col].isin(["Oui", "Non"])])
            if len_votes == 0:
                # print("No yes/no vote for", col)
                pass
            else:
                vote_share = get_splitted_share(df_votes_a, df_votes_b, vote_column=col)
                vote_share["date"] = df.T[col]["VoteDate"]
                vote_share["object"] = col
                votes.append(vote_share)
        dfv = pd.DataFrame(votes)
        print(f"\nTop 2 objects with largest gap:")
        dfv.sort_values("delta", ascending=False).head(5).apply(
            lambda row: print(
                f"Delta: {round(row['delta'], 1)} percent points, %yes <40: {round(row['share b'])}% ({row['yes b']}/{row['yes/no b']}), %yes >=40: {round(row['share a'])}%. Object: {row['object']} ({row['date']})"
            ),
            axis=1,
        )
        party_delta[party_name] = dfv
    else:
        print("No councillor < 40 => no comparison")
# Out:
# UDC:
#  75 >= 40
#  5 < 40
#
# Top 2 objects with largest gap:
# Delta: 86.4 percent points, %yes <40: 0% (0/1), %yes >=40: 86%. Object: Pour sauver des vies en favorisant le don d'organes. Initiative populaire. Loi sur la transplantation. Modification (2021-10-01 08:47:10)
# Delta: 75.6 percent points, %yes <40: 100% (4/4), %yes >=40: 24%. Object: Stop à l’îlot de cherté – pour des prix équitables. Initiative populaire et contre-projet indirect (2021-03-19 09:20:13)
# Delta: 57.4 percent points, %yes <40: 100% (2/2), %yes >=40: 43%. Object: Transport souterrain de marchandises. Loi (2021-12-17 08:32:28)
# Delta: 52.2 percent points, %yes <40: 100% (3/3), %yes >=40: 48%. Object: Reprise et mise en oeuvre du règlement (UE) 2019/1896 du Parlement européen et du Conseil relatif au corps européen de garde-frontières et de garde-côtes et abrogeant les règlements (UE) no 1052/2013 et (UE) 2016/16 24, avec une modification de la loi sur l'asile (2021-10-01 08:44:01)
# Delta: 42.3 percent points, %yes <40: 50% (2/4), %yes >=40: 8%. Object: Doubles impositions. Convention avec la Suède (2020-06-19 10:19:27)
#
# PSS:
#  53 >= 40
#  11 < 40
#
# Top 2 objects with largest gap:
# Delta: 54.2 percent points, %yes <40: 33% (1/3), %yes >=40: 88%. Object: Loi sur la surveillance de la correspondance par poste et télécommunication. Modification (2016-03-18 09:12:25)
# Delta: 50.0 percent points, %yes <40: 50% (2/4), %yes >=40: 100%. Object: Projet fiscal 17 (2018-09-28 10:47:10)
# Delta: 37.9 percent points, %yes <40: 0% (0/9), %yes >=40: 38%. Object: Révision partielle urgente de la loi fédérale sur l'aviation face à la crise Covid-19 (2020-05-06 13:07:51)
# Delta: 30.5 percent points, %yes <40: 67% (2/3), %yes >=40: 97%. Object: Développement de l'acquis de Schengen. Reprise du règlement (UE) 2016/1624 relatif au corps européen de garde-frontières et de garde-côtes (2017-12-15 09:34:43)
# Delta: 25.0 percent points, %yes <40: 75% (6/8), %yes >=40: 100%. Object: Adaptation de l'âge limite en vigueur au sein du Ministère public de la Confédération (2021-10-01 08:49:49)
#
# PLR:
#  40 >= 40
#  2 < 40
#
# Top 2 objects with largest gap:
# Delta: 100.0 percent points, %yes <40: 0% (0/1), %yes >=40: 100%. Object: Loi sur les professions de la santé (2016-09-30 09:10:35)
# Delta: 100.0 percent points, %yes <40: 0% (0/1), %yes >=40: 100%. Object: Echange international automatique de renseignements en matière fiscale. Loi (2015-12-18 08:24:33)
# Delta: 100.0 percent points, %yes <40: 0% (0/1), %yes >=40: 100%. Object: Assistance administrative fiscale. Convention du Conseil de l’Europe et de l’OCDE. Approbation (2015-12-18 08:25:34)
# Delta: 96.4 percent points, %yes <40: 0% (0/1), %yes >=40: 96%. Object: Accord sur la fiscalité de l’épargne entre la Suisse et l’UE. Modification (2016-06-17 09:47:44)
# Delta: 93.3 percent points, %yes <40: 0% (0/1), %yes >=40: 93%. Object: CC. Protection de l’enfant (2017-12-15 09:31:05)
#
# VERT-E-S:
#  25 >= 40
#  8 < 40
#
# Top 2 objects with largest gap:
# Delta: 83.3 percent points, %yes <40: 0% (0/1), %yes >=40: 83%. Object: Pour un revenu de base inconditionnel. Initiative populaire (2015-12-18 08:18:29)
# Delta: 50.0 percent points, %yes <40: 50% (1/2), %yes >=40: 100%. Object: Pour une monnaie à l’abri des crises: émission monétaire uniquement par la Banque nationale! (Initiative Monnaie pleine). Initiative populaire (2017-12-15 09:32:36)
# Delta: 33.3 percent points, %yes <40: 0% (0/3), %yes >=40: 33%. Object: Projet fiscal 17 (2018-09-28 10:47:10)
# Delta: 33.3 percent points, %yes <40: 33% (1/3), %yes >=40: 67%. Object: Loi sur l’asile. Modification (Crédit-cadre migration; deuxième contribution suisse en faveur de certains Etats membres de l’UE) (2019-12-20 09:00:55)
# Delta: 23.1 percent points, %yes <40: 0% (0/6), %yes >=40: 23%. Object: Oui à l’interdiction de se dissimuler le visage. Initiative populaire et contre-projet indirect (2020-06-19 10:04:48)
#
# M-E:
#  30 >= 40
#  1 < 40
#
# Top 2 objects with largest gap:
# Delta: 100.0 percent points, %yes <40: 0% (0/1), %yes >=40: 100%. Object: CO. Droit de la société anonyme (2020-06-19 09:56:05)
# Delta: 75.0 percent points, %yes <40: 0% (0/1), %yes >=40: 75%. Object: Développement de la production d'électricité d'origine hydraulique. Revoir la situation de référence des études d'impact (2019-12-20 08:58:20)
# Delta: 63.0 percent points, %yes <40: 100% (1/1), %yes >=40: 37%. Object: Loi sur les stupéfiants. Modification (2020-09-25 09:45:59)
# Delta: 50.0 percent points, %yes <40: 100% (1/1), %yes >=40: 50%. Object: Mariage civil pour tous (2020-12-18 08:45:07)
# Delta: 46.2 percent points, %yes <40: 0% (0/1), %yes >=40: 46%. Object: Loi sur le service civil. Modification (2020-06-19 10:03:06)
#
# pvl:
#  18 >= 40
#  1 < 40
#
# Top 2 objects with largest gap:
# Delta: 66.7 percent points, %yes <40: 0% (0/1), %yes >=40: 67%. Object: CO. Droit de la société anonyme (2020-06-19 09:56:05)
# Delta: 27.3 percent points, %yes <40: 0% (0/1), %yes >=40: 27%. Object: Pour une Suisse libre de pesticides de synthèse. Initiative populaire (2020-09-25 09:46:41)
# Delta: 21.4 percent points, %yes <40: 0% (0/1), %yes >=40: 21%. Object: Entreprises responsables – pour protéger l’être humain et l’environnement. Initiative populaire (2020-06-19 09:58:36)
# Delta: 14.3 percent points, %yes <40: 0% (0/1), %yes >=40: 14%. Object: Oui à la protection des enfants et des jeunes contre la publicité pour le tabac (enfants et jeunes sans publicité pour le tabac). Initiative populaire (2021-10-01 08:45:45)
# Delta: 7.7 percent points, %yes <40: 100% (1/1), %yes >=40: 92%. Object: Pour des soins infirmiers forts (initiative sur les soins infirmiers). Initiative populaire (2021-06-18 08:28:32)
#
# PDC:
#  10 >= 40
#  0 < 40
# No councillor < 40 => no comparison
#
# PBD:
#  5 >= 40
#  0 < 40
# No councillor < 40 => no comparison

# %%
# Results for 6 political parties with enough <40 y.o. councillors
party_delta.keys()
# Out:
# dict_keys(['UDC', 'PSS', 'PLR', 'VERT-E-S', 'M-E', 'pvl'])

# %%
# Example usage
party_delta['PSS'].sort_values('delta', ascending=False).head(20).round(1)
# Out:
#      yes a  yes b  yes/no a  yes/no b  share a  share b  delta  \
# 13      28      1        32         3     87.5     33.3   54.2
# 144     32      2        32         4    100.0     50.0   50.0
# 155     11      0        29         9     37.9      0.0   37.9
# 113     34      2        35         3     97.1     66.7   30.5
# 262     28      6        28         8    100.0     75.0   25.0
# 4       11      2        25         3     44.0     66.7   22.7
# 120     11      1        20         3     55.0     33.3   21.7
# 87      32      3        34         4     94.1     75.0   19.1
# 111     22      2        27         2     81.5    100.0   18.5
# 259     18      4        22         4     81.8    100.0   18.2
# 116      4      0        24         4     16.7      0.0   16.7
# 124      3      0        32         5      9.4      0.0    9.4
# 114      3      0        35         4      8.6      0.0    8.6
# 214     26      8        28         8     92.9    100.0    7.1
# 129      4      1        30         5     13.3     20.0    6.7
# 132      1      0        23         3      4.3      0.0    4.3
# 0        1      0        36         4      2.8      0.0    2.8
# 248     15      5        23         8     65.2     62.5    2.7
# 261     18      5        26         7     69.2     71.4    2.2
# 194     29      9        29         9    100.0    100.0    0.0
#
#                     date                                             object
# 13   2016-03-18 09:12:25  Loi sur la surveillance de la correspondance p...
# 144  2018-09-28 10:47:10                                   Projet fiscal 17
# 155  2020-05-06 13:07:51  Révision partielle urgente de la loi fédérale ...
# 113  2017-12-15 09:34:43  Développement de l'acquis de Schengen. Reprise...
# 262  2021-10-01 08:49:49  Adaptation de l'âge limite en vigueur au sein ...
# 4    2015-12-18 08:18:29  Pour un revenu de base inconditionnel. Initiat...
# 120  2018-03-16 08:26:45  Pour la souveraineté alimentaire. L’agricultur...
# 87   2017-06-16 08:46:16  Ancrer durablement le taux spécial de TVA appl...
# 111  2017-12-15 09:32:36  Pour une monnaie à l’abri des crises: émission...
# 259  2021-10-01 08:47:10  Pour sauver des vies en favorisant le don d'or...
# 116  2018-03-16 08:20:49  Pour des denrées alimentaires saines et produi...
# 124  2018-03-16 08:38:01  Pour la promotion des voies cyclables et des c...
# 114  2017-12-15 09:35:42  Décision de l’OMC en matière de concurrence à ...
# 214  2020-12-18 08:52:53  Développement de l'acquis de Schengen. Système...
# 129  2018-06-15 09:42:02  Pour la dignité des animaux de rente agricoles...
# 132  2018-06-15 09:48:02  Stopper le mitage - pour un développement dura...
# 0    2015-12-18 08:14:28  Importations de viande assaisonnée. Abolition ...
# 248  2021-10-01 08:36:46  Stop au bradage ruineux du sucre! Pour la sauv...
# 261  2021-10-01 08:48:46  Frais pour l'accueil extrafamilial. Déduction ...
# 194  2020-09-25 09:52:21  Loi sur les précurseurs de substances explosibles
